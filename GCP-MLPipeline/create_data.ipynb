# %%
from pyspark.sql import SparkSession
from sklearn.datasets import load_iris
import pandas as pd

spark = SparkSession.builder.appName("CreateData").getOrCreate()

# Load sklearn dataset
iris = load_iris()

df = pd.DataFrame(
    data=iris.data,
    columns=iris.feature_names
)
df['label'] = iris.target

# Convert to Spark DataFrame
spark_df = spark.createDataFrame(df)

# Save to GCS
spark_df.write.mode("overwrite").csv(
    "gs://spark_mllib/train_data",
    header=True
)

spark.stop()
# Out:
# 26/04/13 12:35:53 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# [Stage 0:>                                                          (0 + 2) / 2]
